# %%
from math import sqrt
from sklearn.datasets import load_digits
mnist = load_digits()
print(mnist.data.shape)

import matplotlib.pyplot as plt
plt.gray()
plt.matshow(mnist.images[0])
plt.show()
print(mnist.images[0])

print(mnist.data[0])
print(mnist.target)

# 1. break data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(mnist.data, mnist.target, mnist.images, test_size=0.2, random_state=42)
plt.hist(mnist.target)
plt.hist(y_train)
plt.hist(y_test)
X_train.shape
y_train.shape

# 2. write a def to compute euclidean distance for every object in  the training dataset
# Return that list
def getNeighbors(test_sample, X_train):
    """"
    Returns the euclidean distance between the test sample and the ..
     
    Parameters
    ----------
    test_sample : Numeric list
        A numeric list of 64 integers between 0 and 16
    X_train : Data Frame
        a data frame of unknown number of digits represented by 64 integers
        
    Returns
    -------
    distances : list
        A list of all the euclidean distances between the test sample and the x_training set
    """

    distances = []
    for index,n in enumerate(X_train):
        sum = 0
        for i in range(len(test_sample)):
            sum += (test_sample[i] - n[i])**2
        distances.append((index, sqrt(sum)))
        
    return distances
#      Assignment:   instead of just one, do all of the testing set give an accuracy out of 360
distances = getNeighbors(X_test[0], X_train)

# 3. Determine what the k nearest neighbors are
k = int(sqrt(len(X_train)))

d_sorted = sorted(distances, key=lambda kv: kv[1])

# creates list of indexs (splits basically)
indexes = [i[0] for i in d_sorted[0:k]]

# 4. Take the mode of the k nearest neighbors to classify our testing sample
from statistics import mode
majority = mode(y_train[indexes])

# 5. check for accuracy with training set
if majority == y_test[0]:
    print("Accurate Prediction: ", majority)
else:
    print("Inaccurate Prediction: ", y_test[0], " Classified as ", majority)
    

# 6. do cross validation with the testing set

# to do when working with full set

# Extra credit to figure out what to do when you have a tie for more : answers (?) flip a coin, choose one that is closest out of the ties,
# Out:
# (1797, 64)
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]
# [0 1 2 ... 8 9 8]
# Accurate Prediction:  6

# %%
from math import sqrt
from sklearn.datasets import load_digits
mnist = load_digits()
print(mnist.data.shape)

import matplotlib.pyplot as plt
plt.gray()
plt.matshow(mnist.images[0])
plt.show()
print(mnist.images[0])

print(mnist.data[0])
print(mnist.target)

# 1. break data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(mnist.data, mnist.target, mnist.images, test_size=0.2, random_state=42)
plt.hist(mnist.target)
plt.hist(y_train)
plt.hist(y_test)
X_train.shape
y_train.shape

accurate_counter = 0
inaccurate_counter = 0
# 2. write a def to compute euclidean distance for every object in  the training dataset
# Return that list
def getNeighbors(test_sample, X_train):
    """"
    Returns the euclidean distance between the test sample and the ..
     
    Parameters
    ----------
    test_sample : Numeric list
        A numeric list of 64 integers between 0 and 16
    X_train : Data Frame
        a data frame of unknown number of digits represented by 64 integers
        
    Returns
    -------
    distances : list
        A list of all the euclidean distances between the test sample and the x_training set
    """

    distances = []
    for index,n in enumerate(X_train):
        sum = 0
        for i in range(len(test_sample)):
            sum += (test_sample[i] - n[i])**2
        distances.append((index, sqrt(sum)))
        
    return distances
#      Assignment:   instead of just one, do all of the testing set give an accuracy out of 360
for counter in range(360):
    distances = getNeighbors(X_test[counter], X_train)

    # 3. Determine what the k nearest neighbors are
    k = int(sqrt(len(X_train)))

    d_sorted = sorted(distances, key=lambda kv: kv[1])

    # creates list of indexs (splits basically)
    indexes = [i[0] for i in d_sorted[0:k]]

    # 4. Take the mode of the k nearest neighbors to classify our testing sample
    from statistics import mode
    majority = mode(y_train[indexes])

    # 5. check for accuracy with training set
    
    if majority == y_test[counter]:
        print("Accurate Prediction: ", majority)
        accurate_counter += 1
        print("Accurate Results: ", accurate_counter)
    else:
        print("Inaccurate Prediction: ", X_test[counter], " Classified as ", majority)
        inaccurate_counter += 1
        print("Inaccurate Results: ", inaccurate_counter)

print("Final Results:")
print("Accurate Results: ", accurate_counter)
print("Inaccurate Results: ", inaccurate_counter)
# 6. do cross validation with the testing set

# to do when working with full set

# Extra credit to figure out what to do when you have a tie for more : answers (?) flip a coin, choose one that is closest out of the ties,
# Out:
# (1797, 64)
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]
# [0 1 2 ... 8 9 8]
# Accurate Prediction:  6
# Accurate Results:  1
# Accurate Prediction:  9
# Accurate Results:  2
# Accurate Prediction:  3
# Accurate Results:  3
# Accurate Prediction:  7
# Accurate Results:  4
# Accurate Prediction:  2
# Accurate Results:  5
# Inaccurate Prediction:  [ 0.  0. 14. 10.  0.  0.  0.  0.  0.  0. 15. 13.  0.  0.  0.  0.  0. 11.
#  16. 16.  2.  0.  0.  0.  0.  3. 10. 16.  5.  0.  0.  0.  0.  0.  0. 14.
#  10.  0.  0.  0.  0.  0.  0. 10. 14.  0.  0.  0.  0.  0.  9. 14. 16. 11.
#   6.  0.  0.  0. 12. 16. 16. 16. 16.  9.]  Classified as  2
# Inaccurate Results:  1
# Accurate Prediction:  5
# Accurate Results:  6
# Accurate Prediction:  2
# Accurate Results:  7
# Accurate Prediction:  5
# Accurate Results:  8
# Accurate Prediction:  2
# Accurate Results:  9
# Accurate Prediction:  1
# Accurate Results:  10
# Accurate Prediction:  9
# Accurate Results:  11
# Accurate Prediction:  4
# Accurate Results:  12
# Accurate Prediction:  0
# Accurate Results:  13
# Accurate Prediction:  4
# Accurate Results:  14
# Accurate Prediction:  2
# Accurate Results:  15
# Accurate Prediction:  3
# Accurate Results:  16
# Accurate Prediction:  7
# Accurate Results:  17
# Accurate Prediction:  8
# Accurate Results:  18
# Accurate Prediction:  8
# Accurate Results:  19
# Accurate Prediction:  4
# Accurate Results:  20
# Accurate Prediction:  3
# Accurate Results:  21
# Accurate Prediction:  9
# Accurate Results:  22
# Accurate Prediction:  7
# Accurate Results:  23
# Accurate Prediction:  5
# Accurate Results:  24
# Accurate Prediction:  6
# Accurate Results:  25
# Accurate Prediction:  3
# Accurate Results:  26
# Accurate Prediction:  5
# Accurate Results:  27
# Accurate Prediction:  6
# Accurate Results:  28
# Accurate Prediction:  3
# Accurate Results:  29
# Accurate Prediction:  4
# Accurate Results:  30
# Accurate Prediction:  9
# Accurate Results:  31
# Accurate Prediction:  1
# Accurate Results:  32
# Accurate Prediction:  4
# Accurate Results:  33
# Accurate Prediction:  4
# Accurate Results:  34
# Accurate Prediction:  6
# Accurate Results:  35
# Accurate Prediction:  9
# Accurate Results:  36
# Accurate Prediction:  4
# Accurate Results:  37
# Accurate Prediction:  7
# Accurate Results:  38
# Accurate Prediction:  6
# Accurate Results:  39
# Accurate Prediction:  6
# Accurate Results:  40
# Accurate Prediction:  9
# Accurate Results:  41
# Accurate Prediction:  1
# Accurate Results:  42
# Accurate Prediction:  3
# Accurate Results:  43
# Accurate Prediction:  6
# Accurate Results:  44
# Accurate Prediction:  1
# Accurate Results:  45
# Accurate Prediction:  3
# Accurate Results:  46
# Accurate Prediction:  0
# Accurate Results:  47
# Accurate Prediction:  6
# Accurate Results:  48
# Accurate Prediction:  5
# Accurate Results:  49
# Accurate Prediction:  5
# Accurate Results:  50
# Accurate Prediction:  1
# Accurate Results:  51
# Accurate Prediction:  9
# Accurate Results:  52
# Accurate Prediction:  5
# Accurate Results:  53
# Accurate Prediction:  6
# Accurate Results:  54
# Accurate Prediction:  0
# Accurate Results:  55
# Accurate Prediction:  9
# Accurate Results:  56
# Accurate Prediction:  0
# Accurate Results:  57
# Accurate Prediction:  0
# Accurate Results:  58
# Accurate Prediction:  1
# Accurate Results:  59
# Accurate Prediction:  0
# Accurate Results:  60
# Accurate Prediction:  4
# Accurate Results:  61
# Accurate Prediction:  5
# Accurate Results:  62
# Accurate Prediction:  2
# Accurate Results:  63
# Accurate Prediction:  4
# Accurate Results:  64
# Accurate Prediction:  5
# Accurate Results:  65
# Accurate Prediction:  7
# Accurate Results:  66
# Accurate Prediction:  0
# Accurate Results:  67
# Accurate Prediction:  7
# Accurate Results:  68
# Accurate Prediction:  5
# Accurate Results:  69
# Accurate Prediction:  9
# Accurate Results:  70
# Inaccurate Prediction:  [ 0.  0.  9. 12. 14.  2.  0.  0.  0.  0. 12.  6.  4.  0.  0.  0.  0.  0.
#  12.  1.  3.  0.  0.  0.  0.  0.  9. 16. 16. 12.  0.  0.  0.  0.  4.  4.
#   0. 12.  6.  0.  0.  0.  0.  0.  0.  4. 12.  0.  0.  0.  9.  7.  4. 10.
#  11.  0.  0.  0.  9. 14. 16. 14.  5.  0.]  Classified as  9
# Inaccurate Results:  2
# Accurate Prediction:  5
# Accurate Results:  71
# Accurate Prediction:  4
# Accurate Results:  72
# Accurate Prediction:  7
# Accurate Results:  73
# Accurate Prediction:  0
# Accurate Results:  74
# Accurate Prediction:  4
# Accurate Results:  75
# Accurate Prediction:  5
# Accurate Results:  76
# Accurate Prediction:  5
# Accurate Results:  77
# Accurate Prediction:  9
# Accurate Results:  78
# Accurate Prediction:  9
# Accurate Results:  79
# Accurate Prediction:  0
# Accurate Results:  80
# Accurate Prediction:  2
# Accurate Results:  81
# Accurate Prediction:  3
# Accurate Results:  82
# Accurate Prediction:  8
# Accurate Results:  83
# Accurate Prediction:  0
# Accurate Results:  84
# Accurate Prediction:  6
# Accurate Results:  85
# Accurate Prediction:  4
# Accurate Results:  86
# Accurate Prediction:  4
# Accurate Results:  87
# Accurate Prediction:  9
# Accurate Results:  88
# Accurate Prediction:  1
# Accurate Results:  89
# Accurate Prediction:  2
# Accurate Results:  90
# Accurate Prediction:  8
# Accurate Results:  91
# Accurate Prediction:  3
# Accurate Results:  92
# Accurate Prediction:  5
# Accurate Results:  93
# Accurate Prediction:  2
# Accurate Results:  94
# Accurate Prediction:  9
# Accurate Results:  95
# Accurate Prediction:  0
# Accurate Results:  96
# Accurate Prediction:  4
# Accurate Results:  97
# Accurate Prediction:  4
# Accurate Results:  98
# Accurate Prediction:  4
# Accurate Results:  99
# Accurate Prediction:  3
# Accurate Results:  100
# Accurate Prediction:  5
# Accurate Results:  101
# Accurate Prediction:  3
# Accurate Results:  102
# Accurate Prediction:  1
# Accurate Results:  103
# Accurate Prediction:  3
# Accurate Results:  104
# Accurate Prediction:  5
# Accurate Results:  105
# Accurate Prediction:  9
# Accurate Results:  106
# Accurate Prediction:  4
# Accurate Results:  107
# Accurate Prediction:  2
# Accurate Results:  108
# Accurate Prediction:  7
# Accurate Results:  109
# Accurate Prediction:  7
# Accurate Results:  110
# Accurate Prediction:  4
# Accurate Results:  111
# Accurate Prediction:  4
# Accurate Results:  112
# Accurate Prediction:  1
# Accurate Results:  113
# Accurate Prediction:  9
# Accurate Results:  114
# Inaccurate Prediction:  [ 0.  0.  0.  8. 15.  8.  0.  0.  0.  0.  3. 16. 12. 16.  4.  0.  0.  0.
#   2. 10.  1. 16.  4.  0.  0.  0.  0.  0.  8. 14.  0.  0.  0.  0.  0.  9.
#  15.  3.  0.  0.  0.  3. 16. 14.  4.  0.  0.  0.  0.  4. 15. 14.  7.  1.
#   0.  0.  0.  0.  0.  9. 12. 14.  4.  0.]  Classified as  8
# Inaccurate Results:  3
# Accurate Prediction:  7
# Accurate Results:  115
# Accurate Prediction:  8
# Accurate Results:  116
# Accurate Prediction:  7
# Accurate Results:  117
# Accurate Prediction:  2
# Accurate Results:  118
# Accurate Prediction:  6
# Accurate Results:  119
# Accurate Prediction:  9
# Accurate Results:  120
# Accurate Prediction:  4
# Accurate Results:  121
# Accurate Prediction:  0
# Accurate Results:  122
# Accurate Prediction:  7
# Accurate Results:  123
# Accurate Prediction:  2
# Accurate Results:  124
# Accurate Prediction:  7
# Accurate Results:  125
# Accurate Prediction:  5
# Accurate Results:  126
# Accurate Prediction:  8
# Accurate Results:  127
# Accurate Prediction:  7
# Accurate Results:  128
# Accurate Prediction:  5
# Accurate Results:  129
# Accurate Prediction:  7
# Accurate Results:  130
# Accurate Prediction:  7
# Accurate Results:  131
# Accurate Prediction:  0
# Accurate Results:  132
# Accurate Prediction:  6
# Accurate Results:  133
# Accurate Prediction:  6
# Accurate Results:  134
# Accurate Prediction:  4
# Accurate Results:  135
# Accurate Prediction:  2
# Accurate Results:  136
# Accurate Prediction:  8
# Accurate Results:  137
# Accurate Prediction:  0
# Accurate Results:  138
# Accurate Prediction:  9
# Accurate Results:  139
# Accurate Prediction:  4
# Accurate Results:  140
# Accurate Prediction:  6
# Accurate Results:  141
# Accurate Prediction:  9
# Accurate Results:  142
# Accurate Prediction:  9
# Accurate Results:  143
# Accurate Prediction:  6
# Accurate Results:  144
# Accurate Prediction:  9
# Accurate Results:  145
# Accurate Prediction:  0
# Accurate Results:  146
# Accurate Prediction:  3
# Accurate Results:  147
# Accurate Prediction:  5
# Accurate Results:  148
# Accurate Prediction:  6
# Accurate Results:  149
# Accurate Prediction:  6
# Accurate Results:  150
# Accurate Prediction:  0
# Accurate Results:  151
# Accurate Prediction:  6
# Accurate Results:  152
# Accurate Prediction:  4
# Accurate Results:  153
# Accurate Prediction:  3
# Accurate Results:  154
# Accurate Prediction:  9
# Accurate Results:  155
# Accurate Prediction:  3
# Accurate Results:  156
# Inaccurate Prediction:  [ 0.  0.  6. 12. 13.  6.  0.  0.  0.  6. 16.  9. 12. 16.  2.  0.  0.  7.
#  16.  9. 15. 13.  0.  0.  0.  0. 11. 15. 16.  4.  0.  0.  0.  0.  0. 12.
#  10.  0.  0.  0.  0.  0.  3. 16.  4.  0.  0.  0.  0.  0.  1. 16.  2.  0.
#   0.  0.  0.  0.  6. 11.  0.  0.  0.  0.]  Classified as  7
# Inaccurate Results:  4
# Accurate Prediction:  7
# Accurate Results:  157
# Accurate Prediction:  2
# Accurate Results:  158
# Accurate Prediction:  9
# Accurate Results:  159
# Accurate Prediction:  0
# Accurate Results:  160
# Accurate Prediction:  4
# Accurate Results:  161
# Accurate Prediction:  5
# Accurate Results:  162
# Accurate Prediction:  3
# Accurate Results:  163
# Accurate Prediction:  6
# Accurate Results:  164
# Accurate Prediction:  5
# Accurate Results:  165
# Inaccurate Prediction:  [ 0.  0.  4. 14. 16. 15.  1.  0.  0.  5. 16.  8.  4. 16.  7.  0.  0.  8.
#  13.  0.  4. 16. 12.  0.  0.  7. 16. 15. 16. 13.  3.  0.  0.  0.  6. 12.
#  16.  4.  0.  0.  0.  0.  0. 11. 12.  0.  0.  0.  0.  0.  0. 16.  7.  0.
#   0.  0.  0.  0.  3. 16.  2.  0.  0.  0.]  Classified as  7
# Inaccurate Results:  5
# Accurate Prediction:  9
# Accurate Results:  166
# Accurate Prediction:  8
# Accurate Results:  167
# Accurate Prediction:  4
# Accurate Results:  168
# Accurate Prediction:  2
# Accurate Results:  169
# Accurate Prediction:  1
# Accurate Results:  170
# Accurate Prediction:  3
# Accurate Results:  171
# Accurate Prediction:  7
# Accurate Results:  172
# Accurate Prediction:  7
# Accurate Results:  173
# Accurate Prediction:  2
# Accurate Results:  174
# Accurate Prediction:  2
# Accurate Results:  175
# Accurate Prediction:  3
# Accurate Results:  176
# Accurate Prediction:  9
# Accurate Results:  177
# Accurate Prediction:  8
# Accurate Results:  178
# Accurate Prediction:  0
# Accurate Results:  179
# Accurate Prediction:  3
# Accurate Results:  180
# Accurate Prediction:  2
# Accurate Results:  181
# Accurate Prediction:  2
# Accurate Results:  182
# Accurate Prediction:  5
# Accurate Results:  183
# Accurate Prediction:  6
# Accurate Results:  184
# Accurate Prediction:  9
# Accurate Results:  185
# Accurate Prediction:  9
# Accurate Results:  186
# Accurate Prediction:  4
# Accurate Results:  187
# Accurate Prediction:  1
# Accurate Results:  188
# Accurate Prediction:  5
# Accurate Results:  189
# Accurate Prediction:  4
# Accurate Results:  190
# Accurate Prediction:  2
# Accurate Results:  191
# Accurate Prediction:  3
# Accurate Results:  192
# Accurate Prediction:  6
# Accurate Results:  193
# Accurate Prediction:  4
# Accurate Results:  194
# Accurate Prediction:  8
# Accurate Results:  195
# Accurate Prediction:  5
# Accurate Results:  196
# Accurate Prediction:  9
# Accurate Results:  197
# Accurate Prediction:  5
# Accurate Results:  198
# Accurate Prediction:  7
# Accurate Results:  199
# Inaccurate Prediction:  [ 0.  0.  5. 12.  8.  0.  1.  0.  0.  0. 11. 16.  5. 13.  6.  0.  0.  0.
#   2. 15. 16. 12.  1.  0.  0.  0.  0. 10. 16.  6.  0.  0.  0.  0.  1. 15.
#  16.  7.  0.  0.  0.  0.  8. 16. 16. 11.  0.  0.  0.  0. 11. 16. 16.  9.
#   0.  0.  0.  0.  6. 12. 12.  3.  0.  0.]  Classified as  1
# Inaccurate Results:  6
# Accurate Prediction:  9
# Accurate Results:  200
# Accurate Prediction:  4
# Accurate Results:  201
# Accurate Prediction:  8
# Accurate Results:  202
# Accurate Prediction:  1
# Accurate Results:  203
# Accurate Prediction:  5
# Accurate Results:  204
# Accurate Prediction:  4
# Accurate Results:  205
# Accurate Prediction:  4
# Accurate Results:  206
# Accurate Prediction:  9
# Accurate Results:  207
# Accurate Prediction:  6
# Accurate Results:  208
# Accurate Prediction:  1
# Accurate Results:  209
# Accurate Prediction:  8
# Accurate Results:  210
# Accurate Prediction:  6
# Accurate Results:  211
# Accurate Prediction:  0
# Accurate Results:  212
# Accurate Prediction:  4
# Accurate Results:  213
# Accurate Prediction:  5
# Accurate Results:  214
# Accurate Prediction:  2
# Accurate Results:  215
# Accurate Prediction:  7
# Accurate Results:  216
# Accurate Prediction:  4
# Accurate Results:  217
# Accurate Prediction:  6
# Accurate Results:  218
# Accurate Prediction:  4
# Accurate Results:  219
# Accurate Prediction:  5
# Accurate Results:  220
# Accurate Prediction:  6
# Accurate Results:  221
# Accurate Prediction:  0
# Accurate Results:  222
# Accurate Prediction:  3
# Accurate Results:  223
# Accurate Prediction:  2
# Accurate Results:  224
# Accurate Prediction:  3
# Accurate Results:  225
# Accurate Prediction:  6
# Accurate Results:  226
# Accurate Prediction:  7
# Accurate Results:  227
# Accurate Prediction:  1
# Accurate Results:  228
# Inaccurate Prediction:  [ 0.  0.  7. 12. 13.  4.  0.  0.  0.  0. 16.  6.  6.  2.  0.  0.  0.  4.
#  13.  7.  8.  2.  0.  0.  0.  7. 16. 10. 10. 14.  1.  0.  0.  2.  2.  0.
#   0. 10.  6.  0.  0.  0.  0.  0.  0.  8.  8.  0.  0.  0. 11.  1.  0. 10.
#   8.  0.  0.  0.  8. 15. 15. 15.  2.  0.]  Classified as  9
# Inaccurate Results:  7
# Accurate Prediction:  1
# Accurate Results:  229
# Accurate Prediction:  4
# Accurate Results:  230
# Accurate Prediction:  7
# Accurate Results:  231
# Accurate Prediction:  6
# Accurate Results:  232
# Accurate Prediction:  8
# Accurate Results:  233
# Inaccurate Prediction:  [ 0.  0.  5. 14. 15.  4.  0.  0.  0.  0.  8. 16. 16. 14.  0.  0.  0.  0.
#   5. 16. 16.  9.  0.  0.  0.  0.  0. 15. 16.  1.  0.  0.  0.  0.  1. 16.
#  13.  0.  0.  0.  0.  0. 11. 15. 14.  5.  0.  0.  0.  0. 12. 12.  8. 15.
#   1.  0.  0.  0.  5. 16. 16. 16.  2.  0.]  Classified as  1
# Inaccurate Results:  8
# Accurate Prediction:  5
# Accurate Results:  234
# Accurate Prediction:  5
# Accurate Results:  235
# Accurate Prediction:  1
# Accurate Results:  236
# Accurate Prediction:  6
# Accurate Results:  237
# Accurate Prediction:  2
# Accurate Results:  238
# Accurate Prediction:  8
# Accurate Results:  239
# Accurate Prediction:  8
# Accurate Results:  240
# Inaccurate Prediction:  [ 0.  0.  0.  8. 10. 14.  3.  0.  0.  1. 13. 13.  9. 12.  8.  0.  0.  6.
#  16.  8.  8. 16.  4.  0.  0.  5. 16. 16. 16.  9.  0.  0.  0.  0.  5.  8.
#  14. 12.  0.  0.  0.  0.  0.  3. 16.  5.  0.  0.  0.  0.  0. 15.  8.  0.
#   0.  0.  0.  0.  1. 12.  2.  0.  0.  0.]  Classified as  7
# Inaccurate Results:  9
# Inaccurate Prediction:  [ 0.  0.  6. 14. 16. 15.  1.  0.  0.  9. 16. 12.  9. 16.  3.  0.  0. 12.
#  16. 11. 14. 13.  0.  0.  0.  7. 15. 16. 14.  0.  0.  0.  0.  0.  2.  8.
#  16.  5.  0.  0.  0.  0.  0.  6. 16.  4.  0.  0.  0.  0.  2. 13. 12.  0.
#   0.  0.  0.  0.  9. 16.  1.  0.  0.  0.]  Classified as  5
# Inaccurate Results:  10
# Accurate Prediction:  7
# Accurate Results:  241
# Accurate Prediction:  6
# Accurate Results:  242
# Accurate Prediction:  2
# Accurate Results:  243
# Accurate Prediction:  2
# Accurate Results:  244
# Accurate Prediction:  2
# Accurate Results:  245
# Accurate Prediction:  3
# Accurate Results:  246
# Accurate Prediction:  4
# Accurate Results:  247
# Accurate Prediction:  8
# Accurate Results:  248
# Accurate Prediction:  8
# Accurate Results:  249
# Accurate Prediction:  3
# Accurate Results:  250
# Accurate Prediction:  6
# Accurate Results:  251
# Accurate Prediction:  0
# Accurate Results:  252
# Accurate Prediction:  9
# Accurate Results:  253
# Accurate Prediction:  7
# Accurate Results:  254
# Accurate Prediction:  7
# Accurate Results:  255
# Accurate Prediction:  0
# Accurate Results:  256
# Accurate Prediction:  1
# Accurate Results:  257
# Accurate Prediction:  0
# Accurate Results:  258
# Accurate Prediction:  4
# Accurate Results:  259
# Accurate Prediction:  5
# Accurate Results:  260
# Accurate Prediction:  1
# Accurate Results:  261
# Accurate Prediction:  5
# Accurate Results:  262
# Accurate Prediction:  3
# Accurate Results:  263
# Accurate Prediction:  6
# Accurate Results:  264
# Accurate Prediction:  0
# Accurate Results:  265
# Accurate Prediction:  4
# Accurate Results:  266
# Accurate Prediction:  1
# Accurate Results:  267
# Accurate Prediction:  0
# Accurate Results:  268
# Accurate Prediction:  0
# Accurate Results:  269
# Accurate Prediction:  3
# Accurate Results:  270
# Accurate Prediction:  6
# Accurate Results:  271
# Accurate Prediction:  5
# Accurate Results:  272
# Accurate Prediction:  9
# Accurate Results:  273
# Accurate Prediction:  7
# Accurate Results:  274
# Accurate Prediction:  3
# Accurate Results:  275
# Accurate Prediction:  5
# Accurate Results:  276
# Accurate Prediction:  5
# Accurate Results:  277
# Accurate Prediction:  9
# Accurate Results:  278
# Accurate Prediction:  9
# Accurate Results:  279
# Accurate Prediction:  8
# Accurate Results:  280
# Accurate Prediction:  5
# Accurate Results:  281
# Accurate Prediction:  3
# Accurate Results:  282
# Accurate Prediction:  3
# Accurate Results:  283
# Accurate Prediction:  2
# Accurate Results:  284
# Accurate Prediction:  0
# Accurate Results:  285
# Accurate Prediction:  5
# Accurate Results:  286
# Accurate Prediction:  8
# Accurate Results:  287
# Accurate Prediction:  3
# Accurate Results:  288
# Accurate Prediction:  4
# Accurate Results:  289
# Accurate Prediction:  0
# Accurate Results:  290
# Accurate Prediction:  2
# Accurate Results:  291
# Accurate Prediction:  4
# Accurate Results:  292
# Accurate Prediction:  6
# Accurate Results:  293
# Accurate Prediction:  4
# Accurate Results:  294
# Accurate Prediction:  3
# Accurate Results:  295
# Accurate Prediction:  4
# Accurate Results:  296
# Accurate Prediction:  5
# Accurate Results:  297
# Accurate Prediction:  0
# Accurate Results:  298
# Accurate Prediction:  5
# Accurate Results:  299
# Accurate Prediction:  2
# Accurate Results:  300
# Accurate Prediction:  1
# Accurate Results:  301
# Accurate Prediction:  3
# Accurate Results:  302
# Accurate Prediction:  1
# Accurate Results:  303
# Accurate Prediction:  4
# Accurate Results:  304
# Accurate Prediction:  1
# Accurate Results:  305
# Accurate Prediction:  1
# Accurate Results:  306
# Accurate Prediction:  7
# Accurate Results:  307
# Accurate Prediction:  0
# Accurate Results:  308
# Accurate Prediction:  1
# Accurate Results:  309
# Accurate Prediction:  5
# Accurate Results:  310
# Accurate Prediction:  2
# Accurate Results:  311
# Accurate Prediction:  1
# Accurate Results:  312
# Accurate Prediction:  2
# Accurate Results:  313
# Accurate Prediction:  8
# Accurate Results:  314
# Accurate Prediction:  7
# Accurate Results:  315
# Accurate Prediction:  0
# Accurate Results:  316
# Accurate Prediction:  6
# Accurate Results:  317
# Accurate Prediction:  4
# Accurate Results:  318
# Accurate Prediction:  8
# Accurate Results:  319
# Accurate Prediction:  8
# Accurate Results:  320
# Accurate Prediction:  5
# Accurate Results:  321
# Accurate Prediction:  1
# Accurate Results:  322
# Accurate Prediction:  8
# Accurate Results:  323
# Accurate Prediction:  4
# Accurate Results:  324
# Accurate Prediction:  5
# Accurate Results:  325
# Accurate Prediction:  8
# Accurate Results:  326
# Accurate Prediction:  7
# Accurate Results:  327
# Accurate Prediction:  9
# Accurate Results:  328
# Accurate Prediction:  8
# Accurate Results:  329
# Inaccurate Prediction:  [ 0.  0.  4.  9. 13. 13.  0.  0.  0.  1. 13. 15.  6.  2.  0.  0.  0.  0.
#   9.  7.  0.  0.  0.  0.  0.  0. 13.  3.  4.  0.  0.  0.  0.  2. 16. 16.
#  16.  8.  0.  0.  0.  2. 11.  3.  0. 10.  4.  0.  0.  0.  2.  5.  4. 15.
#   1.  0.  0.  0.  3. 12. 14.  8.  0.  0.]  Classified as  6
# Inaccurate Results:  11
# Accurate Prediction:  0
# Accurate Results:  330
# Accurate Prediction:  6
# Accurate Results:  331
# Accurate Prediction:  2
# Accurate Results:  332
# Accurate Prediction:  0
# Accurate Results:  333
# Accurate Prediction:  7
# Accurate Results:  334
# Accurate Prediction:  9
# Accurate Results:  335
# Inaccurate Prediction:  [ 0.  0.  2. 13.  4.  0.  0.  0.  0.  0.  8. 14. 11.  0.  0.  0.  0.  0.
#  10.  6. 14.  5.  2.  0.  0.  0.  2. 14. 12. 14.  0.  0.  0.  0.  1. 15.
#  13.  2.  0.  0.  0.  0. 11. 13. 14.  1.  0.  0.  0.  0. 13.  8. 10.  4.
#   0.  0.  0.  0.  2. 11. 16.  7.  0.  0.]  Classified as  1
# Inaccurate Results:  12
# Accurate Prediction:  9
# Accurate Results:  336
# Accurate Prediction:  5
# Accurate Results:  337
# Accurate Prediction:  2
# Accurate Results:  338
# Accurate Prediction:  7
# Accurate Results:  339
# Accurate Prediction:  7
# Accurate Results:  340
# Accurate Prediction:  1
# Accurate Results:  341
# Accurate Prediction:  8
# Accurate Results:  342
# Accurate Prediction:  7
# Accurate Results:  343
# Accurate Prediction:  4
# Accurate Results:  344
# Accurate Prediction:  3
# Accurate Results:  345
# Accurate Prediction:  8
# Accurate Results:  346
# Accurate Prediction:  3
# Accurate Results:  347
# Accurate Prediction:  5
# Accurate Results:  348
# Final Results:
# Accurate Results:  348
# Inaccurate Results:  12
